# %%
import pandas as pd
import univariate as uva

# %%
data = pd.read_csv("hr_analytics.csv")

# %%
uva.uva_numerical(data, ['age'])

# %%
stats = uva.descriptive_stats(data['age'])
stats['mean']
# Out:
# 34.80391548679025
